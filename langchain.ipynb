# %%
#!pip install langchain_google_genai
from langchain_google_genai import GoogleGenerativeAI

import os
#from dotenv import load_dotenv
#load_dotenv()
# Out:
# Requirement already satisfied: langchain_google_genai in c:\users\user\anaconda3\lib\site-packages (2.0.9)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-generativeai<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from langchain_google_genai) (0.8.4)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in c:\users\user\anaconda3\lib\site-packages (from langchain_google_genai) (0.3.35)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain_google_genai) (2.10.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.24.1)
# Requirement already satisfied: google-api-python-client in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.161.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (2.38.0)
# Requirement already satisfied: protobuf in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (5.29.3)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\user\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.26.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (6.0)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain_google_genai) (2.27.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (2.31.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (0.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\user\anaconda3\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.67.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\user\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (4.1.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\user\anaconda3\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\user\anaconda3\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (1.70.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\user\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (3.0.9)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (3.5.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (1.0.7)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain_google_genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (1.26.16)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain_google_genai) (1.2.0)

# %%
#!pip install google.genai

from google import genai

llm = GoogleGenerativeAI(model="gemini-pro", google_api_key="<GEMINI_API_KEY>")

# %%
print(response.text)
# Out:
# Alright, let's break down how AI works.  It's a vast and complex field, but we can simplify it into key concepts:
#
# **1. The Goal: Mimicking Intelligence**
#
# At its core, AI aims to create machines that can perform tasks that typically require human intelligence. This includes things like:
#
# *   **Learning:**  Improving performance over time through experience.
# *   **Reasoning:**  Solving problems and making decisions based on available information.
# *   **Perception:**  Interpreting sensory data (like images, sound, or text).
# *   **Natural Language Processing (NLP):** Understanding and generating human language.
# *   **Problem Solving:** Finding optimal solutions to given challenges.
#
# **2. Key Approaches (and Overlap):**
#
# There are several different approaches to achieving AI, and they often work together:
#
# *   **Machine Learning (ML):** This is the most popular approach today.  Instead of explicitly programming a computer to do something, you *train* it on data.  The machine learns patterns and relationships within the data, and then uses those patterns to make predictions or decisions on new, unseen data.
#
#     *   **Supervised Learning:** The algorithm is trained on a labeled dataset, meaning each piece of data has a known "correct answer." The algorithm learns to map the input data to the correct output.  Think of it like learning with a teacher who provides feedback on your answers.
#         *   **Example:** Training an image recognition system with images of cats and dogs, labeled as "cat" or "dog."
#         *   **Algorithms:**  Linear Regression, Logistic Regression, Support Vector Machines (SVM), Decision Trees, Random Forests, Naive Bayes.
#
#     *   **Unsupervised Learning:** The algorithm is trained on an unlabeled dataset. The goal is to discover hidden patterns, structures, or groupings within the data.  Think of it like exploring data to find interesting things you didn't know were there.
#         *   **Example:** Grouping customers based on their purchasing behavior.
#         *   **Algorithms:** Clustering (K-Means, Hierarchical Clustering), Dimensionality Reduction (Principal Component Analysis - PCA), Anomaly Detection.
#
#     *   **Reinforcement Learning (RL):** The algorithm learns to make decisions in an environment to maximize a reward. It learns through trial and error, receiving feedback in the form of rewards or penalties for its actions.  Think of it like training a dog with treats.
#         *   **Example:** Training a robot to walk, or training an AI to play a game like Go.
#         *   **Algorithms:** Q-Learning, Deep Q-Networks (DQN), Policy Gradients.
#
# *   **Deep Learning (DL):**  A subfield of Machine Learning that uses artificial neural networks with many layers (hence "deep") to analyze data. These networks are inspired by the structure of the human brain. Deep Learning excels at complex tasks like image recognition, speech recognition, and natural language processing because they can learn intricate patterns from massive amounts of data.
#
#     *   **How it works:**  Data is fed into the input layer of the neural network.  Each layer consists of interconnected "neurons" that perform calculations and pass the results to the next layer.  The network learns by adjusting the strengths of the connections between neurons (called "weights") to minimize errors in its predictions.
#     *   **Types of Neural Networks:**
#         *   **Convolutional Neural Networks (CNNs):**  Excellent for image and video analysis.
#         *   **Recurrent Neural Networks (RNNs):** Designed for processing sequential data like text and time series.  LSTMs (Long Short-Term Memory) are a popular type of RNN.
#         *   **Transformers:**  A more recent architecture that has revolutionized NLP, powering models like BERT and GPT.
#
# *   **Rule-Based Systems (Expert Systems):**  These systems use a set of predefined rules to make decisions. They are often used in situations where the logic is well-defined and can be explicitly encoded.
#
#     *   **Example:**  A medical diagnosis system that uses rules based on symptoms to suggest possible diagnoses.
#     *   **Drawbacks:**  Can be difficult to maintain and update as the knowledge base grows.  Not good at handling uncertainty or incomplete information.
#
# *   **Natural Language Processing (NLP):**  Focuses on enabling computers to understand, interpret, and generate human language.  It involves techniques like:
#
#     *   **Tokenization:** Breaking text into individual words or phrases.
#     *   **Part-of-Speech Tagging:** Identifying the grammatical role of each word (e.g., noun, verb, adjective).
#     *   **Named Entity Recognition:** Identifying and classifying named entities (e.g., people, organizations, locations).
#     *   **Sentiment Analysis:** Determining the emotional tone of a piece of text.
#     *   **Machine Translation:** Translating text from one language to another.
#     *   **Text Generation:** Creating new text, such as articles, stories, or code.
#
# **3. The Process: Data, Training, and Deployment**
#
# Here's a simplified overview of the process of building and using an AI system:
#
# 1.  **Data Collection:**  Gather a large and relevant dataset. The quality and quantity of data are crucial for AI performance.
# 2.  **Data Preprocessing:** Clean and prepare the data for training. This may involve handling missing values, removing noise, and transforming the data into a suitable format.
# 3.  **Model Selection:** Choose an appropriate AI algorithm or model for the task. This depends on the type of problem, the available data, and the desired performance.
# 4.  **Training:**  Train the model on the data.  During training, the model learns to identify patterns and relationships in the data.
# 5.  **Validation and Testing:** Evaluate the model's performance on a separate dataset to ensure it generalizes well to new data.
# 6.  **Deployment:** Deploy the trained model into a real-world application.
# 7.  **Monitoring and Maintenance:**  Continuously monitor the model's performance and retrain it as needed to maintain accuracy and adapt to changing data.
#
# **4. Key Components and Technologies:**
#
# *   **Algorithms:**  The mathematical formulas and procedures that guide the learning process. (See examples above in ML section)
# *   **Data:**  The fuel that powers AI systems.  The more data available, the better the AI can learn.
# *   **Hardware:** Powerful computers (often with GPUs - Graphics Processing Units) are needed to train and run complex AI models.  Cloud computing platforms like AWS, Azure, and Google Cloud are frequently used.
# *   **Software Frameworks:**  Libraries and tools that simplify the development of AI applications. Popular frameworks include TensorFlow, PyTorch, scikit-learn, and Keras.
# *   **Programming Languages:**  Python is the dominant language for AI development, but other languages like R, Java, and C++ are also used.
#
# **5. Important Considerations:**
#
# *   **Bias:**  AI models can inherit biases from the data they are trained on.  It's crucial to be aware of potential biases and take steps to mitigate them.
# *   **Explainability:**  Understanding why an AI model makes a particular decision can be challenging, especially with complex deep learning models.  Explainable AI (XAI) is a growing field focused on making AI more transparent and understandable.
# *   **Ethics:**  AI raises important ethical considerations related to privacy, fairness, and accountability.
# *   **Security:**  AI systems can be vulnerable to attacks.  It's important to secure AI systems and protect them from malicious actors.
#
# **In summary:**  AI is a broad field focused on creating intelligent machines. Machine Learning, especially Deep Learning, is a dominant approach that uses data to train models that can perform complex tasks. The process involves data collection, training, validation, and deployment. Considerations like bias, explainability, and ethics are critical for responsible AI development.
#
# This is a simplified overview.  Each of these areas can be explored in much greater depth.  I hope this provides a good starting point for understanding how AI works!

# %%
#!pip install langchain_experimental
from langchain_experimental.sql import SQLDatabaseChain

from langchain.utilities import SQLDatabase
# Out:
# Requirement already satisfied: langchain_experimental in c:\users\user\anaconda3\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from langchain_experimental) (0.3.17)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in c:\users\user\anaconda3\lib\site-packages (from langchain_experimental) (0.3.35)
# Requirement already satisfied: langchain<1.0.0,>=0.3.18 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.18)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.8.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (8.2.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.7.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.4.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in c:\users\user\anaconda3\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.10.6)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\user\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.18->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.6)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.28->langchain_experimental) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.21.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.1)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.0)

# %%
#!pip install pymysql
db_user = "root"
db_password = "root"
db_host = "localhost"
db_name = "chinook"

db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}",sample_rows_in_table_info=3)


print(db.table_info)
# Out:
# Collecting pymysql
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/0c/94/e4181a1f6286f545507528c78016e00065ea913276888db2262507693ce5/PyMySQL-1.1.1-py3-none-any.whl.metadata
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/45.0 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 45.0/45.0 kB 560.2 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
#
# CREATE TABLE album (
# 	`AlbumId` INTEGER NOT NULL,
# 	`Title` VARCHAR(160) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`ArtistId` INTEGER NOT NULL,
# 	PRIMARY KEY (`AlbumId`),
# 	CONSTRAINT `FK_AlbumArtistId` FOREIGN KEY(`ArtistId`) REFERENCES artist (`ArtistId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from album table:
# AlbumId	Title	ArtistId
# 1	For Those About To Rock We Salute You	1
# 2	Balls to the Wall	2
# 3	Restless and Wild	2
# */
#
#
# CREATE TABLE artist (
# 	`ArtistId` INTEGER NOT NULL,
# 	`Name` VARCHAR(120) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`ArtistId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from artist table:
# ArtistId	Name
# 1	AC/DC
# 2	Accept
# 3	Aerosmith
# */
#
#
# CREATE TABLE customer (
# 	`CustomerId` INTEGER NOT NULL,
# 	`FirstName` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`LastName` VARCHAR(20) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`Company` VARCHAR(80) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Address` VARCHAR(70) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`City` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`State` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Country` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`PostalCode` VARCHAR(10) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Phone` VARCHAR(24) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Fax` VARCHAR(24) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Email` VARCHAR(60) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`SupportRepId` INTEGER,
# 	PRIMARY KEY (`CustomerId`),
# 	CONSTRAINT `FK_CustomerSupportRepId` FOREIGN KEY(`SupportRepId`) REFERENCES employee (`EmployeeId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from customer table:
# CustomerId	FirstName	LastName	Company	Address	City	State	Country	PostalCode	Phone	Fax	Email	SupportRepId
# 1	Luís	Gonçalves	Embraer - Empresa Brasileira de Aeronáutica S.A.	Av. Brigadeiro Faria Lima, 2170	São José dos Campos	SP	Brazil	12227-000	+55 (12) 3923-5555	+55 (12) 3923-5566	luisg@embraer.com.br	3
# 2	Leonie	Köhler	None	Theodor-Heuss-Straße 34	Stuttgart	None	Germany	70174	+49 0711 2842222	None	leonekohler@surfeu.de	5
# 3	François	Tremblay	None	1498 rue Bélanger	Montréal	QC	Canada	H2G 1A7	+1 (514) 721-4711	None	ftremblay@gmail.com	3
# */
#
#
# CREATE TABLE employee (
# 	`EmployeeId` INTEGER NOT NULL,
# 	`LastName` VARCHAR(20) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`FirstName` VARCHAR(20) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`Title` VARCHAR(30) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`ReportsTo` INTEGER,
# 	`BirthDate` DATETIME,
# 	`HireDate` DATETIME,
# 	`Address` VARCHAR(70) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`City` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`State` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Country` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`PostalCode` VARCHAR(10) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Phone` VARCHAR(24) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Fax` VARCHAR(24) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Email` VARCHAR(60) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`EmployeeId`),
# 	CONSTRAINT `FK_EmployeeReportsTo` FOREIGN KEY(`ReportsTo`) REFERENCES employee (`EmployeeId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from employee table:
# EmployeeId	LastName	FirstName	Title	ReportsTo	BirthDate	HireDate	Address	City	State	Country	PostalCode	Phone	Fax	Email
# 1	Adams	Andrew	General Manager	None	1962-02-18 00:00:00	2002-08-14 00:00:00	11120 Jasper Ave NW	Edmonton	AB	Canada	T5K 2N1	+1 (780) 428-9482	+1 (780) 428-3457	andrew@chinookcorp.com
# 2	Edwards	Nancy	Sales Manager	1	1958-12-08 00:00:00	2002-05-01 00:00:00	825 8 Ave SW	Calgary	AB	Canada	T2P 2T3	+1 (403) 262-3443	+1 (403) 262-3322	nancy@chinookcorp.com
# 3	Peacock	Jane	Sales Support Agent	2	1973-08-29 00:00:00	2002-04-01 00:00:00	1111 6 Ave SW	Calgary	AB	Canada	T2P 5M5	+1 (403) 262-3443	+1 (403) 262-6712	jane@chinookcorp.com
# */
#
#
# CREATE TABLE genre (
# 	`GenreId` INTEGER NOT NULL,
# 	`Name` VARCHAR(120) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`GenreId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from genre table:
# GenreId	Name
# 1	Rock
# 2	Jazz
# 3	Metal
# */
#
#
# CREATE TABLE invoice (
# 	`InvoiceId` INTEGER NOT NULL,
# 	`CustomerId` INTEGER NOT NULL,
# 	`InvoiceDate` DATETIME NOT NULL,
# 	`BillingAddress` VARCHAR(70) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`BillingCity` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`BillingState` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`BillingCountry` VARCHAR(40) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`BillingPostalCode` VARCHAR(10) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Total` DECIMAL(10, 2) NOT NULL,
# 	PRIMARY KEY (`InvoiceId`),
# 	CONSTRAINT `FK_InvoiceCustomerId` FOREIGN KEY(`CustomerId`) REFERENCES customer (`CustomerId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from invoice table:
# InvoiceId	CustomerId	InvoiceDate	BillingAddress	BillingCity	BillingState	BillingCountry	BillingPostalCode	Total
# 1	2	2021-01-01 00:00:00	Theodor-Heuss-Straße 34	Stuttgart	None	Germany	70174	1.98
# 2	4	2021-01-02 00:00:00	Ullevålsveien 14	Oslo	None	Norway	0171	3.96
# 3	8	2021-01-03 00:00:00	Grétrystraat 63	Brussels	None	Belgium	1000	5.94
# */
#
#
# CREATE TABLE invoiceline (
# 	`InvoiceLineId` INTEGER NOT NULL,
# 	`InvoiceId` INTEGER NOT NULL,
# 	`TrackId` INTEGER NOT NULL,
# 	`UnitPrice` DECIMAL(10, 2) NOT NULL,
# 	`Quantity` INTEGER NOT NULL,
# 	PRIMARY KEY (`InvoiceLineId`),
# 	CONSTRAINT `FK_InvoiceLineInvoiceId` FOREIGN KEY(`InvoiceId`) REFERENCES invoice (`InvoiceId`),
# 	CONSTRAINT `FK_InvoiceLineTrackId` FOREIGN KEY(`TrackId`) REFERENCES track (`TrackId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from invoiceline table:
# InvoiceLineId	InvoiceId	TrackId	UnitPrice	Quantity
# 1	1	2	0.99	1
# 2	1	4	0.99	1
# 3	2	6	0.99	1
# */
#
#
# CREATE TABLE mediatype (
# 	`MediaTypeId` INTEGER NOT NULL,
# 	`Name` VARCHAR(120) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`MediaTypeId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from mediatype table:
# MediaTypeId	Name
# 1	MPEG audio file
# 2	Protected AAC audio file
# 3	Protected MPEG-4 video file
# */
#
#
# CREATE TABLE playlist (
# 	`PlaylistId` INTEGER NOT NULL,
# 	`Name` VARCHAR(120) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	PRIMARY KEY (`PlaylistId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from playlist table:
# PlaylistId	Name
# 1	Music
# 2	Movies
# 3	TV Shows
# */
#
#
# CREATE TABLE playlisttrack (
# 	`PlaylistId` INTEGER NOT NULL,
# 	`TrackId` INTEGER NOT NULL,
# 	PRIMARY KEY (`PlaylistId`, `TrackId`),
# 	CONSTRAINT `FK_PlaylistTrackPlaylistId` FOREIGN KEY(`PlaylistId`) REFERENCES playlist (`PlaylistId`),
# 	CONSTRAINT `FK_PlaylistTrackTrackId` FOREIGN KEY(`TrackId`) REFERENCES track (`TrackId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from playlisttrack table:
# PlaylistId	TrackId
# 1	1
# 1	2
# 1	3
# */
#
#
# CREATE TABLE track (
# 	`TrackId` INTEGER NOT NULL,
# 	`Name` VARCHAR(200) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci NOT NULL,
# 	`AlbumId` INTEGER,
# 	`MediaTypeId` INTEGER NOT NULL,
# 	`GenreId` INTEGER,
# 	`Composer` VARCHAR(220) CHARACTER SET utf8mb3 COLLATE utf8mb3_general_ci,
# 	`Milliseconds` INTEGER NOT NULL,
# 	`Bytes` INTEGER,
# 	`UnitPrice` DECIMAL(10, 2) NOT NULL,
# 	PRIMARY KEY (`TrackId`),
# 	CONSTRAINT `FK_TrackAlbumId` FOREIGN KEY(`AlbumId`) REFERENCES album (`AlbumId`),
# 	CONSTRAINT `FK_TrackGenreId` FOREIGN KEY(`GenreId`) REFERENCES genre (`GenreId`),
# 	CONSTRAINT `FK_TrackMediaTypeId` FOREIGN KEY(`MediaTypeId`) REFERENCES mediatype (`MediaTypeId`)
# )COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
#
# /*
# 3 rows from track table:
# TrackId	Name	AlbumId	MediaTypeId	GenreId	Composer	Milliseconds	Bytes	UnitPrice
# 1	For Those About To Rock (We Salute You)	1	1	1	Angus Young, Malcolm Young, Brian Johnson	343719	11170334	0.99
# 2	Balls to the Wall	2	2	1	U. Dirkschneider, W. Hoffmann, H. Frank, P. Baltes, S. Kaufmann, G. Hoffmann	342562	5510424	0.99
# 3	Fast As a Shark	3	2	1	F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman	230619	3990994	0.99
# */

# %%
#!pip install langchain
from langchain.chains import create_sql_query_chain

chain = create_sql_query_chain(llm, db)
response = chain.invoke({"question": "Give me artists and thieir numbers"})
response
# Out:
# '```sql\nSELECT\n  `Name`,\n  COUNT(*)\nFROM artist\nGROUP BY\n  `Name`\nORDER BY\n  `Name`;\n```'

# %%
cleaned_query = response.strip('```sql\n').strip('\n```')
print(cleaned_query)
# Out:
# SELECT
#   `Name`,
#   COUNT(*)
# FROM artist
# GROUP BY
#   `Name`
# ORDER BY
#   `Name`;

# %%
result = db.run(cleaned_query)
print(result)
# Out:
# [('A Cor Do Som', 1), ('Aaron Copland & London Symphony Orchestra', 1), ('Aaron Goldberg', 1), ('AC/DC', 1), ('Academy of St. Martin in the Fields & Sir Neville Marriner', 1), ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 1), ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 1), ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 1), ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', 1), ('Accept', 1), ('Adrian Leaper & Doreen de Feis', 1), ('Aerosmith', 1), ("Aerosmith & Sierra Leone's Refugee Allstars", 1), ('Aisha Duo', 1), ('Alanis Morissette', 1), ('Alberto Turco & Nova Schola Gregoriana', 1), ('Alice In Chains', 1), ('Amy Winehouse', 1), ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 1), ('Antal Doráti & London Symphony Orchestra', 1), ('Antônio Carlos Jobim', 1), ('Apocalyptica', 1), ('Aquaman', 1), ('Audioslave', 1), ('Avril Lavigne', 1), ('Azymuth', 1), ('Baby Consuelo', 1), ('BackBeat', 1), ('Banda Black Rio', 1), ('Barão Vermelho', 1), ('Barry Wordsworth & BBC Concert Orchestra', 1), ('Battlestar Galactica', 1), ('Battlestar Galactica (Classic)', 1), ('Bebel Gilberto', 1), ('Ben Harper', 1), ('Berliner Philharmoniker & Hans Rosbaud', 1), ('Berliner Philharmoniker & Herbert Von Karajan', 1), ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 1), ('Big & Rich', 1), ('Billy Cobham', 1), ('Black Eyed Peas', 1), ('Black Label Society', 1), ('Black Sabbath', 1), ('Body Count', 1), ('Boston Symphony Orchestra & Seiji Ozawa', 1), ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 1), ('Bruce Dickinson', 1), ('Buddy Guy', 1), ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 1), ('Caetano Veloso', 1), ('Cake', 1), ('Calexico', 1), ('Cássia Eller', 1), ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 1), ('Charlie Brown Jr.', 1), ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 1), ('Chicago Symphony Orchestra & Fritz Reiner', 1), ('Chico Buarque', 1), ('Chico Science & Nação Zumbi', 1), ('Choir Of Westminster Abbey & Simon Preston', 1), ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 1), ('Chris Cornell', 1), ('Christina Aguilera featuring BigElf', 1), ("Christopher O'Riley", 1), ('Cidade Negra', 1), ('Cláudio Zoli', 1), ('Corinne Bailey Rae', 1), ('Creedence Clearwater Revival', 1), ('David Coverdale', 1), ('Deep Purple', 1), ('Def Leppard', 1), ('Dennis Chambers', 1), ('Dhani Harrison & Jakob Dylan', 1), ('DJ Dolores & Orchestra Santa Massa', 1), ('Djavan', 1), ('Dread Zeppelin', 1), ('Ed Motta', 1), ('Edo de Waart & San Francisco Symphony', 1), ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', 1), ('Elis Regina', 1), ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 1), ('Emerson String Quartet', 1), ('English Concert & Trevor Pinnock', 1), ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 1), ('Eric Clapton', 1), ('Eugene Ormandy', 1), ('Faith No More', 1), ('Falamansa', 1), ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 1), ('Fernanda Porto', 1), ('Foo Fighters', 1), ('Frank Sinatra', 1), ('Frank Zappa & Captain Beefheart', 1), ('Fretwork', 1), ('Funk Como Le Gusta', 1), ('Gene Krupa', 1), ('Gerald Moore', 1), ('Gilberto Gil', 1), ('Godsmack', 1), ('Gonzaguinha', 1), ('Göteborgs Symfoniker & Neeme Järvi', 1), ('Green Day', 1), ("Guns N' Roses", 1), ('Gustav Mahler', 1), ('Gustavo & Andres Veiga & Salazar', 1), ('Habib Koité and Bamada', 1), ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 1), ('Hermeto Pascoal', 1), ('Heroes', 1), ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 1), ('House Of Pain', 1), ('Incognito', 1), ('Instituto', 1), ('Iron Maiden', 1), ('Itzhak Perlman', 1), ('Jack Johnson', 1), ("Jack's Mannequin & Mick Fleetwood", 1), ('Jac ...
